# %% [markdown]
# ---
# title: "About"
# ---
#
# About this site

# %% [markdown]
# <h1> More information about me: </h1>
# I enjoy making Quarto websites!
#
# <h2> My question: </h2>
# I wonder how many quarto websites I will make for this course.
#
# <h3> My thought: <h3>
# Hopefully at least a few more.

# %%
import matplotlib.pyplot as plt

plt.plot([5, 6, 7, 8], [4, 3, 2, 1])
plt.title("Arbitrary Plot")
plt.xlabel("Dance Countoff")
plt.ylabel("Count(s) until dance begins")
plt.show()
